# %% [markdown]
# ## **Courses**
#
#
# 1. [Long-Term Agentic Memory with LangGraph](https://www.deeplearning.ai/short-courses/long-term-agentic-memory-with-langgraph/?utm_campaign=langchainC6-launch&utm_medium=video&utm_source=youtube&utm_content=teaser)
# 2. [The Complete LangChain & LLMs Guide](https://www.coursera.org/learn/packt-the-complete-langchain-llms-guide-ep8du)
# 3. [LangChain & Large Language Models Courses](https://learn.activeloop.ai/)
# 4. [(freecodecamp)The Agentic AI Handbook: A Beginner's Guide to Autonomous Intelligent Agents](https://www.freecodecamp.org/news/the-agentic-ai-handbook/)
# 5. [(freecodecamp)Learn LangGraph and Build Conversational AI with Python](https://www.freecodecamp.org/news/learn-langgraph-and-build-conversational-ai-with-python/)
# 6. [(Deep learning) AI Agents in LangGraph](https://www.deeplearning.ai/short-courses/ai-agents-in-langgraph/)

# %% [markdown]
# ## **Youtube**
#
# 1. [LangChain Crash Course For Beginners 2025](https://www.youtube.com/watch?v=at6XrRRdOQo&t=2s)
# 2. [LangChain Mastery in 2025](https://www.youtube.com/watch?v=Cyv-dgv80kE)

# %% [markdown]
# ## **Blogs**
#
# 1. [AI Engineers Guide to LangChain](https://www.aurelio.ai/learn/langchain-when-to-use)
# 2. [A Practical Guide to Building Local RAG Applications with LangChain](https://machinelearningmastery.com/a-practical-guide-to-building-local-rag-applications-with-langchain)
# 3. [Understanding LangChain Runnables (mirascope)](https://mirascope.com/blog/langchain-runnables/)

# %% [markdown]
# ## **Repo**
#
# 1. [(mirascope) Understanding LangChain Runnables](https://mirascope.com/blog/langchain-runnables)
